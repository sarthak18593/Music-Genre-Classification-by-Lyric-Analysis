# %%
import requests

# %%
page = requests.get("http://www.songlyrics.com/musicgenres.php")

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
genre_link = []
for i in soup.find_all(class_='td-item td-text-big'):
    genre_link.append(tuple([i.get_text(),i.find('a').get('href')]))

# %%
genres = ['Folk','Rock','R&B;','Hip Hop/Rap','Pop','Jazz']
genre_link
# Out:
# [('Acoustic', 'acoustic-lyrics.php'),
#  ('Alternative', 'alternative-lyrics.php'),
#  ('Folk', 'folk-lyrics.php'),
#  ('Country', 'country-music-lyrics.php'),
#  ('Rock', 'rock-lyrics.php'),
#  ('Christian', 'christian-lyrics.php'),
#  ('R&B;', 'r-and-b-lyrics.php'),
#  ('Hip Hop/Rap', 'hip-hop-rap-lyrics.php'),
#  ('Dance', 'dance-lyrics.php'),
#  ('Latin', 'latin-lyrics.php'),
#  ('Blues', 'blues-lyrics.php'),
#  ('Electronic', 'electronic-lyrics.php'),
#  ('Funk', 'funk-lyrics.php'),
#  ('Jazz', 'jazz-lyrics.php'),
#  ('Pop', 'pop-lyrics.php'),
#  ('Soul', 'soul-lyrics.php'),
#  ('Soundtrack', 'soundtrack-lyrics.php'),
#  ('Adult Contemporary', 'adult-contemporary-lyrics.php'),
#  ('Classical', 'classical-lyrics.php'),
#  ('Reggae', 'reggae-lyrics.php'),
#  ('World', 'world-lyrics.php'),
#  ('New Age', 'new-age-lyrics.php'),
#  ('African', 'african-lyrics.php'),
#  ('Ska', 'ska-lyrics.php'),
#  ('Avant-Garde', 'avant-garde-lyrics.php'),
#  ("Children's Music", 'childrens-music-lyrics.php'),
#  ('Holiday', 'holiday-lyrics.php'),
#  ('Comedy', 'comedy-lyrics.php'),
#  ('Musical', 'musical-lyrics.php'),
#  ('Vocal', 'vocal-lyrics.php'),
#  ('Instrumental', 'instrumental-lyrics.php'),
#  ('Oldies', 'oldies-lyrics.php'),
#  ('All Time', 'http://www.songlyrics.com/news/top-songs/all-time/'),
#  ('Christian', 'http://www.songlyrics.com/news/top-genres/christian/'),
#  ('Country', 'http://www.songlyrics.com/news/top-genres/country-music/'),
#  ('Hip Hop/Rap', 'http://www.songlyrics.com/news/top-genres/hip-hop-rap/'),
#  ('Pop', 'http://www.songlyrics.com/news/top-genres/pop/'),
#  ('R&B', 'http://www.songlyrics.com/news/top-genres/rhythm-blues/'),
#  ('Rock', 'http://www.songlyrics.com/news/top-genres/rock/')]

# %%
new_genre_link = []
for i in genre_link:
    if(i[0] in genres):
        new_genre_link.append(i)

# %%
new_genre_link = new_genre_link[:-3]

# %%
new_genre_link
# Out:
# [('Folk', 'folk-lyrics.php'),
#  ('Rock', 'rock-lyrics.php'),
#  ('R&B;', 'r-and-b-lyrics.php'),
#  ('Hip Hop/Rap', 'hip-hop-rap-lyrics.php'),
#  ('Jazz', 'jazz-lyrics.php'),
#  ('Pop', 'pop-lyrics.php')]

# %%
pop_page = requests.get("http://www.songlyrics.com/pop-lyrics.php")

# %%
new_genre_link[2] = list(new_genre_link[2])
new_genre_link[2][0] = 'R&B'
new_genre_link[2] = tuple(new_genre_link[2])
new_genre_link[3] = list(new_genre_link[3])
new_genre_link[3][0] = 'Hip-Hop'
new_genre_link[3] = tuple(new_genre_link[3])

# %%
new_genre_link
# Out:
# [('Folk', 'folk-lyrics.php'),
#  ('Rock', 'rock-lyrics.php'),
#  ('R&B', 'r-and-b-lyrics.php'),
#  ('Hip-Hop', 'hip-hop-rap-lyrics.php'),
#  ('Jazz', 'jazz-lyrics.php'),
#  ('Pop', 'pop-lyrics.php')]

# %%
soup = BeautifulSoup(pop_page.content,'html.parser')

# %%
album_link = []
flag = 0
for table in soup.find_all(class_='tracklist'):
    if(flag==1):
        for i in table.find_all(class_="td-item td-last"):
            print (i)
            print ('\n')
            album_link.append(tuple(['pop',i.find_all('span')[-1].get_text(),i.find('a').get('title'),i.find('a').get('href')]))
    flag += 1
# Out:
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/ed-sheeran/-divide/" title="÷ (Divide) Album">÷ (Divide) <span>Album</span></a></h3><span>Ed Sheeran</span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/bruno-mars/24k-magic/" title="24K Magic Album">24K Magic <span>Album</span></a></h3><span>Bruno Mars</span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/soundtrack/beauty-and-the-beast-ost/" title="Beauty and the Beast OST Album">Beauty and the Beast OST <span>Album</span></a></h3><span>Soundtrack</span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/the-shins/heartworms/" title="Heartworms Album">Heartworms <span>Album</span></a></h3><span>The Shins</span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/aaron-watson/vaquero/" title="Vaquero Album">Vaquero <span>Album</span></a></h3><span>Aaron Watson</span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/jus-jack/stargazing/" title="Stargazing Album">Stargazing <span>Album</span></a></h3><span>Jus Jack</span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/justin-hurwitz/la-la-land-original-motion-picture-score/" title="La La Land (Original Motion Picture Score) Album">La La Land (Original Motion Picture Score) <span>Album</span></a></h3><span>Justin Hurwitz</span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/chris-stapleton/traveller/" title="Traveller Album">Traveller <span>Album</span></a></h3><span>Chris Stapleton </span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/j-j-hairston/you-deserve-it/" title="You Deserve It Album">You Deserve It <span>Album</span></a></h3><span>J.J. Hairston</span></td>
#
#
# <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/twenty-one-pilots/blurryface/" title="Blurryface Album">Blurryface <span>Album</span></a></h3><span>Twenty One Pilots</span></td>

# %%
album_link
# Out:
# [('pop',
#   'Ed Sheeran',
#   '÷ (Divide) Album',
#   'http://www.songlyrics.com/ed-sheeran/-divide/'),
#  ('pop',
#   'Bruno Mars',
#   '24K Magic Album',
#   'http://www.songlyrics.com/bruno-mars/24k-magic/'),
#  ('pop',
#   'Soundtrack',
#   'Beauty and the Beast OST Album',
#   'http://www.songlyrics.com/soundtrack/beauty-and-the-beast-ost/'),
#  ('pop',
#   'The Shins',
#   'Heartworms Album',
#   'http://www.songlyrics.com/the-shins/heartworms/'),
#  ('pop',
#   'Aaron Watson',
#   'Vaquero Album',
#   'http://www.songlyrics.com/aaron-watson/vaquero/'),
#  ('pop',
#   'Jus Jack',
#   'Stargazing Album',
#   'http://www.songlyrics.com/jus-jack/stargazing/'),
#  ('pop',
#   'Justin Hurwitz',
#   'La La Land (Original Motion Picture Score) Album',
#   'http://www.songlyrics.com/justin-hurwitz/la-la-land-original-motion-picture-score/'),
#  ('pop',
#   'Chris Stapleton ',
#   'Traveller Album',
#   'http://www.songlyrics.com/chris-stapleton/traveller/'),
#  ('pop',
#   'J.J. Hairston',
#   'You Deserve It Album',
#   'http://www.songlyrics.com/j-j-hairston/you-deserve-it/'),
#  ('pop',
#   'Twenty One Pilots',
#   'Blurryface Album',
#   'http://www.songlyrics.com/twenty-one-pilots/blurryface/')]

# %%
album_link[0][2].split('Album')[0].replace(' ','')
# Out:
# '÷(Divide)'

# %%
req = requests.get(album_link[0][3])

# %%
pop = BeautifulSoup(req.content)
# Out:
# /Users/purvank/anaconda3/lib/python3.5/site-packages/beautifulsoup4-4.5.3-py3.5.egg/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /Users/purvank/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
song_link = []
table = pop.find(class_='tracklist')

# %%
for i in table.find_all('tr'):
    song_link.append(tuple([i.find('a').get('title'),i.find('a').get('href')]))

# %%
song_link[1][0].split('Lyrics')[0]
# Out:
# 'Stressed Out '

# %%
song_link
# Out:
# [("Billy, Don't Be a Hero Lyrics Ed Sheeran",
#   'http://www.songlyrics.com/ed-sheeran/billy-don-t-be-a-hero-lyrics/'),
#  ('Eraser Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/eraser-lyrics/'),
#  ('Castle on the Hill Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/castle-on-the-hill-lyrics/'),
#  ('Dive Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/dive-lyrics/'),
#  ('Shape of You Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/shape-of-you-lyrics/'),
#  ('Perfect Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/perfect-lyrics/'),
#  ('Galway Girl Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/galway-girl-lyrics/'),
#  ('Happier Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/happier-lyrics/'),
#  ('New Man Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/new-man-lyrics/'),
#  ("Hearts Don't Break Around Here Lyrics Ed Sheeran",
#   'http://www.songlyrics.com/ed-sheeran/hearts-don-t-break-around-here-lyrics/'),
#  ('What Do I Know? Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/what-do-i-know-lyrics/'),
#  ('How Would You Feel (Paean) Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/how-would-you-feel-paean-lyrics/'),
#  ('Supermarket Flowers Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/supermarket-flowers-lyrics/'),
#  ('Barcelona Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/barcelona-lyrics/'),
#  ('Bibia Be Ye Ye Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/bibia-be-ye-ye-lyrics/'),
#  ('Nancy Mulligan Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/nancy-mulligan-lyrics/'),
#  ('Save Myself Lyrics Ed Sheeran',
#   'http://www.songlyrics.com/ed-sheeran/save-myself-lyrics/')]

# %%
firstlyrics = requests.get(song_link[0][1])

# %%
lyrics = BeautifulSoup(firstlyrics.content)
# Out:
# /Users/purvank/anaconda3/lib/python3.5/site-packages/beautifulsoup4-4.5.3-py3.5.egg/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /Users/purvank/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
lyric = lyrics.find(id='songLyricsDiv').get_text()

# %%
lyric
# Out:
# "Scared of my own image\r\nScared of my own immaturity\r\nScared of my own ceiling\r\nScared I'll die of uncertainty\r\nFear might be the death of me\r\nFear leads to anxiety\r\nDon't know what's inside of me\n\r\nDon't forget ab-b-b-b-bout me\r\nDon't forget ab-b-b-b-bout me\r\nEven when I doubt you\r\nI'm no good without you, no, no\n\r\nTemperature's dropping\r\nTemperature's dropping\r\nI'm not sure if I can\r\nSee this ever stopping\r\nShaking hands with the dark parts of my thoughts, no\r\nYou are all that I've got, no\n\r\nDon't forget ab-b-b-b-bout me\r\nDon't forget ab-b-b-b-bout me\r\nEven when I doubt you\r\nI'm no good without you, no, no no no no\n\r\nGnawing on the bishops\r\nClaw away at this system\r\nRepeating simple phrases\r\nSomeone holy insisted\r\nWant the mark he's made on my skin\r\nTo mean something to me again\r\nHope you haven't left without me\r\nHope you haven't left without me, please\n\r\nDon't forget ab-b-b-b-bout me\r\nDon't forget ab-b-b-b-bout me\r\nEven when I doubt you\r\nI'm no good without you, no\n\r\nDon't forget ab-b-b-b-bout me\r\nDon't forget ab-b-b-b-bout me\r\nEven when I doubt you\r\nI'm no good without you, no no no no\n\r\nHey! Hey!\r\nDon't forget about me, no\r\nHey! Hey!\r\nDon't forget about me, no\r\nHey! Hey!\r\nDon't forget about me, no\r\nHey! Hey!\r\nDon't forget about me, no "

# %%
pop_matrix = []
for i in album_link:
    req = requests.get(i[:][3])
    pop = BeautifulSoup(req.content,'html.parser')
    table = pop.find(class_='tracklist')
    song_link = []
    for k in table.find_all('tr'):
        song_link.append(tuple([k.find('a').get('title'),k.find('a').get('href')]))
    for l in song_link:
        lyrics = requests.get(l[:][1])
        lyr = BeautifulSoup(lyrics.content,'html.parser')
        lyric = lyr.find(id='songLyricsDiv').get_text()
        if(len(lyric)>300):
            row = []
            row.append('pop')
            row.append(i[:][1])
            row.append(i[:][2].split('Album')[0])
            row.append(l[:][0].split('Lyrics')[0])
            row.append(lyric)
            pop_matrix.append(row)

# %%
import pandas as pd

# %%
pop_d = pd.DataFrame(pop_matrix,columns=['Genre','Artist','Album','Song','Lyrics'])

# %%
pop_d
# Out:
#     Genre             Artist        Album                             Song  \
# 0     pop         Ed Sheeran  ÷ (Divide)                           Eraser
# 1     pop         Ed Sheeran  ÷ (Divide)               Castle on the Hill
# 173  I'm fairly local, I've been around\nI've seen ...
# 174  Scared of my own image\r\nScared of my own imm...
# 175  Scared of my own image\r\nScared of my own imm...
# 176  Scared of my own image\r\nScared of my own imm...
# 177  Scared of my own image\r\nScared of my own imm...
# 178  Scared of my own image\r\nScared of my own imm...
# 179  [Verse 1] [x2]\r\nI'm a goner\r\nSomebody catc...
# 180  [Verse 1] [x2]\r\nI'm a goner\r\nSomebody catc...
# 181  [Verse 1] [x2]\r\nI'm a goner\r\nSomebody catc...
# 182  [Verse 1] [x2]\r\nI'm a goner\r\nSomebody catc...
# 183  [Verse 1] [x2]\r\nI'm a goner\r\nSomebody catc...
#
# [184 rows x 5 columns]

# %%
pop_d.drop_duplicates('Song')
# Out:
#     Genre             Artist                                        Album  \
# 0     pop         Ed Sheeran                                  ÷ (Divide)
# 1     pop         Ed Sheeran                                  ÷ (Divide)
# 2     pop         Ed Sheeran                                  ÷ (Divide)
# 3     pop         Ed Sheeran                                  ÷ (Divide)
# 4     pop         Ed Sheeran                                  ÷ (Divide)
# 5     pop         Ed Sheeran                                  ÷ (Divide)
# 6     pop         Ed Sheeran                                  ÷ (Divide)
# 7     pop         Ed Sheeran                                  ÷ (Divide)
# 8     pop         Ed Sheeran                                  ÷ (Divide)
# 9     pop         Ed Sheeran                                  ÷ (Divide)
# 10    pop         Ed Sheeran                                  ÷ (Divide)
# 11    pop         Ed Sheeran                                  ÷ (Divide)
# 12    pop         Ed Sheeran                                  ÷ (Divide)
# 13    pop         Ed Sheeran                                  ÷ (Divide)
# 14    pop         Ed Sheeran                                  ÷ (Divide)
# 15    pop         Ed Sheeran                                  ÷ (Divide)
# 16    pop         Bruno Mars                                   24K Magic
# 17    pop         Bruno Mars                                   24K Magic
# 18    pop         Bruno Mars                                   24K Magic
# 19    pop         Bruno Mars                                   24K Magic
# 20    pop         Bruno Mars                                   24K Magic
# 21    pop         Bruno Mars                                   24K Magic
# 23    pop         Bruno Mars                                   24K Magic
# 25    pop         Bruno Mars                                   24K Magic
# 26    pop         Bruno Mars                                   24K Magic
# 32    pop         Bruno Mars                                   24K Magic
# 34    pop         Bruno Mars                                   24K Magic
# 35    pop         Soundtrack                    Beauty and the Beast OST
# 36    pop         Soundtrack                    Beauty and the Beast OST
# 37    pop         Soundtrack                    Beauty and the Beast OST
# ..    ...                ...                                          ...
# 74    pop     Justin Hurwitz  La La Land (Original Motion Picture Score)
# 75    pop   Chris Stapleton                                    Traveller
# 76    pop   Chris Stapleton                                    Traveller
# 77    pop   Chris Stapleton                                    Traveller
# 80    pop   Chris Stapleton                                    Traveller
# 83    pop   Chris Stapleton                                    Traveller
# 85    pop   Chris Stapleton                                    Traveller
# 87    pop   Chris Stapleton                                    Traveller
# 89    pop   Chris Stapleton                                    Traveller
# 90    pop   Chris Stapleton                                    Traveller
# 91    pop   Chris Stapleton                                    Traveller
# 92    pop   Chris Stapleton                                    Traveller
# 93    pop   Chris Stapleton                                    Traveller
# 95    pop   Chris Stapleton                                    Traveller
# 99    pop  Twenty One Pilots                                  Blurryface
# 100   pop  Twenty One Pilots                                  Blurryface
# 101   pop  Twenty One Pilots                                  Blurryface
# 14   I was twenty four years old\r\nWhen I met the ...
# 15   I gave all my oxygen to people that could brea...
# 16   Tonight\nI just want to take you higher\nThrow...
# 17    Produced By Shampoo Press & Curl\n\n\r\n[Vers...
# 18   [Intro: Unnamed Man & Bruno Mars]\r\nNow look ...
# 19    Produced By Shampoo Press & Curl\n\n\r\n[Vers...
# 20    Produced By Shampoo Press & Curl\n\n\r\n[Vers...
# 21   Tonight\nI just want to take you higher\nThrow...
# 23   Let's take our time tonight, girl\nAbove us al...
# 25    Produced By Shampoo Press & Curl\n\n\r\n[Vers...
# 26    Produced By Shampoo Press & Curl\n\n\r\n[Vers...
# 32    Produced By Shampoo Press & Curl\n\n\r\n[Vers...
# 34    Produced By Shampoo Press & Curl\n\n\r\n[Vers...
# 35   [Verse 1: Ariana Grande]\r\nTale as old as tim...
# 36   [Verse 1]\r\nHow does a moment last forever?\r...
# 37   [MADAME DE GARDEROBE]\r\nTale as old as time\r...
# ..                                                 ...
# 74   [Sebastian's Verse: Ryan Gosling & (Emma Stone...
# 75   [Verse 1]\r\nHoney load up your questions\r\nA...
# 76   [Verse 1]\r\nLivin' hard was easy when I was y...
# 77   Used to spend my nights out in a barroom\nLiqu...
# 80   COUNTRY RAP POP ROCK LIT R&B; NEWS HISTORY SCR...
# 83   [Verse 1]\r\nStreet lights along the highway\r...
# 85   [Verse 1]\r\nWhen I think of you and the first...
# 87   There are days that I can walk around like I'm...
# 89   [Verse 1]\r\nThere’s a bottle on the dresser b...
# 90   [Verse 1]\r\nShe took down the photograph\r\nO...
# 91   [Verse 1]\r\nWhen I think of you and the first...
# 92   [Chorus]\r\nDaddy doesn’t pray anymore\r\nI gu...
# 93   [Verse 1]\r\nWell, she said, she didn’t love m...
# 95   [Verse 1]\r\nWe drove all night to Billings, M...
# 99   Help me polarize\nHelp me polarize\nHelp me do...
# 100  I wish I found some better sounds no one's eve...
# 101  Sometimes you've got to bleed to know,\nThat y...
# 102  They say "stay in your lane boy, lane boy"\nBu...
# 103  There's an infestation in my mind's imaginatio...
# 104  My shadow tilts its head at me\nSpirits in the...
# 106  Na Na Na Na Oh Oh\r\nNa Na Na Na Oh Oh\r\nNa N...
# 107  Scared of my own image\r\nScared of my own imm...
# 109  [Verse 1]\r\nWe don't believe what's on TV\r\n...
# 110  No no no no no no\r\nYeah yeah yeah yeah yeah ...
# 112  [Verse 1]\r\nI don't know why\r\nI just feel I...
# 113  [Verse 1] [x2]\r\nI'm a goner\r\nSomebody catc...
# 119  Yeah, yeah, yeah\nWe don't believe what's on T...
# 124  I just wanna stay in the sun where I find\nI k...
# 162  Sometimes you've got to bleed to know,\nThat y...
# 168  I'm fairly local, I've been around\nI've seen ...
#
# [94 rows x 5 columns]

# %%
import urllib

# %%
def song_scrapper():
    song_matrix = []
    for i in new_genre_link:
        print ()
        genre_page = requests.get('http://www.songlyrics.com/'+i[1])
        soup = BeautifulSoup(genre_page.content,'html.parser')
        album_link = []
        flag = 0
        for table in soup.find_all(class_='tracklist'):
            if(flag==1):
                for j in table.find_all(class_="td-item td-last"):
                    album_link.append(tuple([i[0],j.find_all('span')[-1].get_text(),j.find('a').get('title'),j.find('a').get('href')]))
            flag += 1
        for k in album_link:
            req = requests.get(k[:][3])
            pop = BeautifulSoup(req.content,'html.parser')
            table = pop.find(class_='tracklist')
            song_link = []
            for l in table.find_all('tr'):
                song_link.append(tuple([l.find('a').get('title'),l.find('a').get('href')]))
            for m in song_link:
                if(m[:][1][0]=='/'):
                    lyrics = requests.get('http://www.songlyrics.com/'+m[:][1])
                else:
                    lyrics = requests.get(m[:][1])
                lyr = BeautifulSoup(lyrics.content,'html.parser')
                lyric = lyr.find(id='songLyricsDiv').get_text()
                if(len(lyric)>300):
                    row = []
                    row.append(k[0])
                    row.append(k[:][1])
                    row.append(k[:][2].split('Album')[0])
                    row.append(m[:][0].split('Lyrics')[0])
                    row.append(lyric)
                    song_matrix.append(row)
    return song_matrix

# %%
matrix = song_scrapper()

# %%
len(matrix)
# Out:
# 4221

# %%
data = pd.DataFrame(matrix,columns=['genre','artist','album','song','lyrics'])

# %%
d = data

# %%
d = d.drop_duplicates('song')

# %%
len(d)
# Out:
# 3501

# %%
d.groupby('genre').count()
# Out:
#          artist  album  song  lyrics
# genre
# Folk        478    478   478     478
# Hip-Hop     118    118   118     118
# Jazz       1583   1583  1583    1583
# Pop          66     66    66      66
# R&B        1135   1135  1135    1135
# Rock        121    121   121     121

# %%
import pandas as pd

# %%
data = pd.read_csv('Song_Lyrics.csv')

# %%
data
# Out:
#      genre            artist                                        album  \
# 0     Folk    Regina Spektor                                         Far
# 1     Folk    Regina Spektor                                         Far
# 2     Folk    Regina Spektor                                         Far
# 3     Folk    Regina Spektor                                         Far
# 4     Folk    Regina Spektor                                         Far
# 5     Folk    Regina Spektor                                         Far
# 6     Folk    Regina Spektor                                         Far
# 7     Folk    Regina Spektor                                         Far
# 8     Folk    Regina Spektor                                         Far
# 9     Folk    Regina Spektor                                         Far
# 10    Folk    Regina Spektor                                         Far
# 11    Folk    Regina Spektor                                         Far
# 12    Folk    Regina Spektor                                         Far
# 13    Folk    Regina Spektor                                         Far
# 14    Folk    Regina Spektor                                         Far
# 15    Folk    Regina Spektor                                         Far
# 16    Folk    Regina Spektor                                         Far
# 17    Folk    Regina Spektor                                         Far
# 18    Folk    Regina Spektor                                         Far
# 19    Folk     Tracy Chapman                               Miscellaneous
# 20    Folk     Tracy Chapman                               Miscellaneous
# 21    Folk     Tracy Chapman                               Miscellaneous
# 22    Folk     Tracy Chapman                               Miscellaneous
# 23    Folk     Tracy Chapman                               Miscellaneous
# 24    Folk     Tracy Chapman                               Miscellaneous
# 25    Folk     Tracy Chapman                               Miscellaneous
# 26    Folk     Tracy Chapman                               Miscellaneous
# 27    Folk     Tracy Chapman                               Miscellaneous
# 28    Folk     Tracy Chapman                               Miscellaneous
# 29    Folk     Tracy Chapman                               Miscellaneous
# ...    ...               ...                                          ...
# 3471   Pop         The Shins                                  Heartworms
# 3472   Pop      Aaron Watson                                     Vaquero
# 3473   Pop      Aaron Watson                                     Vaquero
# 3474   Pop      Aaron Watson                                     Vaquero
# 3475   Pop      Aaron Watson                                     Vaquero
# 3476   Pop      Aaron Watson                                     Vaquero
# 3477   Pop      Aaron Watson                                     Vaquero
